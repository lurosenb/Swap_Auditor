# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
random.seed(42)
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score, train_test_split

# %%
data = make_classification(n_samples=50, 
                           n_features=2, 
                           n_informative=2,
                           n_redundant=0, 
                           n_classes=2,
                           n_clusters_per_class=1, 
                           scale=10.0,
                           random_state=42) # class is split evenly, half 1 and half 0

df = pd.DataFrame(data[0], columns=["a","b"])
labels = pd.DataFrame(data[1], columns=["class"])

df_full = pd.concat([df, labels], axis=1)

num_true = 24 # number of true labels to assign to M (and false to F)
num_false = 1 # number of false labels to assign to M (and true to F)

df_full['male'] = 0 # in this example, 0 means female and 1 means male

df_true = df_full[df_full['class'] == 1]
df_false = df_full[df_full['class'] == 0]

df_true = df_true.reset_index()
df_false = df_false.reset_index()

rand_true = random.sample(range(len(df_true)), num_true)
rand_false = random.sample(range(len(df_false)), num_false)

df_true.loc[rand_true, 'male'] = 1
df_false.loc[rand_false, 'male'] = 1

df_full = pd.concat([df_true, df_false])
df_full = df_full.set_index('index')
df_full = df_full.sample(frac=1) # shuffle

df = df_full[['a', 'b', 'male']]
labels = df_full['class']

df_train = df.copy()
df_train['male'] = 0

X_train, X_test, y_train, y_test = train_test_split(df_train, labels, random_state=42)

# model = RandomForestClassifier()
model = LogisticRegression()

# Cross val score
print(np.mean(cross_val_score(model, X_train, y_train, cv=3, scoring='roc_auc')))

# Fit and train on test.
model.fit(X_train, y_train)
print(roc_auc_score(y_test, model.predict_proba(X_test)[:, 1]))
# Out:
# 0.9619047619047619
# 1.0

# %%
# "Fair" model
# create AdversarialDebiasing model
# reset tensorflow graph
from aif360.algorithms.inprocessing import AdversarialDebiasing
import tensorflow as tf
tf.reset_default_graph()

# start tensorflow session
sess = tf.Session()

debiased_model = AdversarialDebiasing(
    privileged_groups = [{'male': 1}],
    unprivileged_groups = [{'male': 0}],
    scope_name = 'debiased_classifier',
    debias = True,
    sess = sess)

# fit the model to training data
debiased_model.fit(X_train)

# make predictions on training and test data
dataset_debiasing_train = debiased_model.predict(X_train)
dataset_debiasing_test = debiased_model.predict(y_train)

print(roc_auc_score(y_test, model.predict_proba(dataset_debiasing_test)[:, 1]))
# Close session
sess.close()

# %%
pd.concat([df, labels], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qj/gh_j11514m37mqtfrlr885k40000gn/T/ipykernel_43175/262845756.py in <module>
# ----> 1 pd.concat([df, labels], axis=1)
#
# NameError: name 'pd' is not defined

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
a = df.to_numpy()[:,0]
b = df.to_numpy()[:,1]
male = df.to_numpy()[:,2]

ax.scatter(a, b, c=labels.to_numpy())

ax.set_xlabel('a')
ax.set_ylabel('b')

plt.show()

# %%
from swap_auditor import NaiveSwapAuditor
df['id'] = np.arange(len(df))
new = NaiveSwapAuditor(data=df, predictor=model, id_column="id",protected_classes=['male'], target_col='class')
new.calculate_all_stability(marginal_features=['a','b'])

# %%
b_coeff = model.intercept_[0]
w1, w2, w3 = model.coef_.T
c = -b_coeff/w2
m = -w1/w2

a_min, a_max = min(a) - 1, max(a) + 1

x = np.array([a_min, a_max])
y = m*x + c

plt.plot(x, y, 'k', ls='--')
plt.scatter(a, b, c=labels.to_numpy())
plt.xlabel('a')
plt.ylabel('b')
for i, txt in enumerate(df['id']):
    plt.annotate(txt, (a[i], b[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qj/gh_j11514m37mqtfrlr885k40000gn/T/ipykernel_42913/510005303.py in <module>
# ----> 1 b_coeff = model.intercept_[0]
#       2 w1, w2, w3 = model.coef_.T
#       3 c = -b_coeff/w2
#       4 m = -w1/w2
#       5
#
# NameError: name 'model' is not defined

# %%
plt.plot(x, y, 'k', ls='--')
plt.scatter(a, b, c=male) # think M = yellow, F = purple?
plt.xlabel('a')
plt.ylabel('b')
for i, txt in enumerate(df['id']):
    plt.annotate(txt, (a[i], b[i]))

# %%
endpoint_0, endpoint_1 = np.array([a_min, y[0]]), np.array([a_max, y[-1]])

def get_euclidean_distance(a_x, b_x):
    return np.cross(endpoint_1 - endpoint_0, endpoint_0 - np.array([a_x, b_x]))/np.linalg.norm(endpoint_1 - endpoint_0)

df['euclidean_distance'] = df.apply(lambda x: get_euclidean_distance(x.a, x.b), axis=1)
df['stability'] = df.apply(lambda x: new._retrieve_stability_individual(int(x.id))[0], axis=1)
df['class'] = labels
print(df)
# Out:
#                a          b  male  id  euclidean_distance  stability  class
# index
# 1       7.758093   2.866289     0   0            2.443143   0.253333      0
# 30     12.477635   8.943453     1   1           -4.701146   0.386667      1
# 32     -8.381404  15.455396     1   2           -5.198602   0.386667      1
# 13     22.973474   7.847482     1   3           -6.546714   0.426667      1
# 43     11.110598  11.968945     1   4           -7.231381   0.386667      1
# 6       5.404613  10.982430     0   5           -4.707270   0.946667      0
# 46      7.118019   6.773804     1   6           -1.135589   0.360000      1
# 12      0.284000  10.615357     1   7           -2.940184   0.386667      1
# 24     12.982104  -8.017408     0   8           11.460629   0.360000      0
# 37     15.118039 -28.229776     0   9           30.296827   0.360000      0
# 23     13.022998   8.077314     1  10           -4.019325   0.386667      1
# 38      6.995736 -14.096321     1  11           18.956490   0.946667      0
# 2      12.409632   2.078656     0  12            1.915402   0.280000      0
# 0      15.979427 -28.787773     0  13           30.595206   0.360000      0
# 20      3.674841  10.527960     1  14           -3.792722   0.386667      1
# 4       7.807282  10.641737     1  15           -5.043436   0.386667      1
# 26     20.549949   7.463783     1  16           -5.508574   0.426667      1
# 42     25.979765   5.940964     1  17           -5.544682   0.400000      1
# 31      6.302559  10.326288     0  18           -4.324660   0.960000      1
# 28     10.309102 -15.875044     0  19           19.750886   0.360000      0
# 48     11.375774  -4.878652     0  20            8.887627   0.360000      0
# 27     -5.779117  12.846769     1  21           -3.410189   0.386667      1
# 10      5.381261  11.895412     1  22           -5.578288   0.386667      1
# 3       6.038349 -23.142847     0  23           27.915545   0.373333      0
# 9      16.818857   9.447381     1  24           -6.384500   0.400000      1
# 34     14.818515 -23.134092     0  25           25.482085   0.360000      0
# 22     11.588354 -10.293834     0  26           14.033453   0.360000      0
# 16      2.511160  -1.432883     0  27            8.024264   0.413333      0
# 35      7.532118  10.848228     1  28           -5.165897   0.386667      1
# 17      9.606250  -1.624628     0  29            6.248916   0.360000      0
# 41     13.617455   1.841625     0  30            1.809617   0.293333      0
# 18     19.533959   7.394593     1  31           -5.161462   0.413333      1
# 44     17.942810 -15.607032     0  32           17.384900   0.360000      0
# 49     13.665585   9.399281     1  33           -5.467350   0.386667      1
# 11     -5.401310  13.844243     1  34           -4.473211   0.386667      1
# 40     13.783839 -19.266793     0  35           22.050992   0.360000      0
# 47     13.151833 -10.602302     0  36           13.898095   0.360000      0
# 29     12.691980   8.401020     1  37           -4.239014   0.386667      1
# 5       1.982810  11.064654     1  38           -3.841208   0.386667      1
# 8      17.590225  -1.866832     0  39            4.276557   0.360000      0
# 36     19.176588   7.235894     1  40           -4.910232   0.400000      1
# 7      11.440276 -11.787997     0  41           15.510393   0.360000      0
# 15     24.617950   5.719115     1  42           -4.955335   0.360000      1
# 19      4.057696  10.629828     1  43           -3.996371   0.386667      1
# 21     17.347118  -5.135771     0  44            7.485485   0.360000      0
# 25     16.250953 -28.947064     0  45           30.673307   0.360000      0
# 14     11.645455 -27.068026     0  46           30.139380   0.360000      0
# 45     26.096158   6.606337     1  47           -6.216321   0.413333      1
# 39      2.157592 -15.208184     0  48           21.361379   0.413333      0
# 33     12.178208   0.483908     0  49            3.512035   0.333333      0

# %%
df_high = df[df['stability'] > 0.8]
df_high
# Out:
#               a          b  male  id  euclidean_distance  stability  class
# index
# 6      5.404613  10.982430     0   5            -4.70727   0.946667      0
# 38     6.995736 -14.096321     1  11            18.95649   0.946667      0
# 31     6.302559  10.326288     0  18            -4.32466   0.960000      1

# %%
plt.scatter(df['euclidean_distance'], df['stability'])
plt.xlabel('Euclidean distance')
plt.ylabel('stability')
plt.show()

# %%
plt.scatter(np.abs(df['euclidean_distance']), df['stability'])
plt.xlabel('Euclidean distance')
plt.ylabel('stability')
plt.show()

# %%
m = df[df['male'] == 1]
f = df[df['male'] == 0]

print(f'Average male stability: {m["stability"].var()}')
print(f'Average female stability: {f["stability"].var()}')
# Out:
# Average male stability: 0.012570074074074072
# Average female stability: 0.02878399999999999
