# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
random.seed(42)
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score, train_test_split

# %%
data = make_classification(n_samples=50, 
                           n_features=2, 
                           n_informative=2,
                           n_redundant=0, 
                           n_classes=2,
                           n_clusters_per_class=1, 
                           scale=10.0,
                           random_state=42) # class is split evenly, half 1 and half 0

df = pd.DataFrame(data[0], columns=["a","b"])
labels = pd.DataFrame(data[1], columns=["class"])

df_full = pd.concat([df, labels], axis=1)

num_true = 24 # number of true labels to assign to M (and false to F)
num_false = 1 # number of false labels to assign to M (and true to F)

df_full['male'] = 0 # in this example, 0 means female and 1 means male

df_true = df_full[df_full['class'] == 1]
df_false = df_full[df_full['class'] == 0]

df_true = df_true.reset_index()
df_false = df_false.reset_index()

rand_true = random.sample(range(len(df_true)), num_true)
rand_false = random.sample(range(len(df_false)), num_false)

df_true.loc[rand_true, 'male'] = 1
df_false.loc[rand_false, 'male'] = 1

df_full = pd.concat([df_true, df_false])
df_full = df_full.set_index('index')
df_full = df_full.sample(frac=1) # shuffle

df = df_full[['a', 'b', 'male']]
labels = df_full['class']

df_train = df.copy()
df_train['male'] = 0

X_train, X_test, y_train, y_test = train_test_split(df_train, labels, random_state=42)

# model = RandomForestClassifier()
model = LogisticRegression()

# Cross val score
print(np.mean(cross_val_score(model, X_train, y_train, cv=3, scoring='roc_auc')))

# Fit and train on test.
model.fit(X_train, y_train)
print(roc_auc_score(y_test, model.predict_proba(X_test)[:, 1]))
# Out:
# 0.9603174603174603
# 1.0

# %%
# "Fair" model
# create AdversarialDebiasing model
# reset tensorflow graph
from aif360.algorithms.inprocessing import AdversarialDebiasing
import tensorflow as tf
tf.reset_default_graph()

# start tensorflow session
sess = tf.Session()

debiased_model = AdversarialDebiasing(
    privileged_groups = [{'male': 1}],
    unprivileged_groups = [{'male': 0}],
    scope_name = 'debiased_classifier',
    debias = True,
    sess = sess)

# fit the model to training data
debiased_model.fit(X_train)

# make predictions on training and test data
dataset_debiasing_train = debiased_model.predict(X_train)
dataset_debiasing_test = debiased_model.predict(y_train)

print(roc_auc_score(y_test, model.predict_proba(dataset_debiasing_test)[:, 1]))
# Close session
sess.close()

# %%
pd.concat([df, labels], axis=1)
# Out:
#                a          b  male  class
# index
# 20      3.674841  10.527960     1      1
# 31      6.302559  10.326288     0      1
# 23     13.022998   8.077314     1      1
# 4       7.807282  10.641737     1      1
# 8      17.590225  -1.866832     0      0
# 49     13.665585   9.399281     1      1
# 18     19.533959   7.394593     1      1
# 12      0.284000  10.615357     1      1
# 40     13.783839 -19.266793     0      0
# 45     26.096158   6.606337     1      1
# 22     11.588354 -10.293834     0      0
# 28     10.309102 -15.875044     0      0
# 47     13.151833 -10.602302     0      0
# 27     -5.779117  12.846769     1      1
# 48     11.375774  -4.878652     0      0
# 26     20.549949   7.463783     1      1
# 9      16.818857   9.447381     1      1
# 15     24.617950   5.719115     1      1
# 33     12.178208   0.483908     0      0
# 13     22.973474   7.847482     1      1
# 1       7.758093   2.866289     0      0
# 2      12.409632   2.078656     0      0
# 37     15.118039 -28.229776     0      0
# 0      15.979427 -28.787773     0      0
# 46      7.118019   6.773804     1      1
# 42     25.979765   5.940964     1      1
# 25     16.250953 -28.947064     0      0
# 14     11.645455 -27.068026     0      0
# 34     14.818515 -23.134092     0      0
# 16      2.511160  -1.432883     0      0
# 24     12.982104  -8.017408     0      0
# 39      2.157592 -15.208184     0      0
# 19      4.057696  10.629828     1      1
# 38      6.995736 -14.096321     1      0
# 7      11.440276 -11.787997     0      0
# 36     19.176588   7.235894     1      1
# 21     17.347118  -5.135771     0      0
# 17      9.606250  -1.624628     0      0
# 35      7.532118  10.848228     1      1
# 3       6.038349 -23.142847     0      0
# 29     12.691980   8.401020     1      1
# 11     -5.401310  13.844243     1      1
# 10      5.381261  11.895412     1      1
# 41     13.617455   1.841625     0      0
# 5       1.982810  11.064654     1      1
# 43     11.110598  11.968945     1      1
# 6       5.404613  10.982430     0      0
# 30     12.477635   8.943453     1      1
# 32     -8.381404  15.455396     1      1
# 44     17.942810 -15.607032     0      0

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
a = df.to_numpy()[:,0]
b = df.to_numpy()[:,1]
male = df.to_numpy()[:,2]

ax.scatter(a, b, c=labels.to_numpy())

ax.set_xlabel('a')
ax.set_ylabel('b')

plt.show()

# %%
from swap_auditor import NaiveSwapAuditor
df['id'] = np.arange(len(df))
new = NaiveSwapAuditor(data=df, predictor=model, id_column="id",protected_classes=['male'], target_col='class')
new.calculate_all_stability(marginal_features=['a','b'])

# %%
b_coeff = model.intercept_[0]
w1, w2, w3 = model.coef_.T
c = -b_coeff/w2
m = -w1/w2

a_min, a_max = min(a) - 1, max(a) + 1

x = np.array([a_min, a_max])
y = m*x + c

plt.plot(x, y, 'k', ls='--')
plt.scatter(a, b, c=labels.to_numpy())
plt.xlabel('a')
plt.ylabel('b')
for i, txt in enumerate(df['id']):
    plt.annotate(txt, (a[i], b[i]))

# %%
plt.plot(x, y, 'k', ls='--')
plt.scatter(a, b, c=male) # think M = yellow, F = purple?
plt.xlabel('a')
plt.ylabel('b')
for i, txt in enumerate(df['id']):
    plt.annotate(txt, (a[i], b[i]))

# %%
endpoint_0, endpoint_1 = np.array([a_min, y[0]]), np.array([a_max, y[-1]])

def get_euclidean_distance(a_x, b_x):
    return np.cross(endpoint_1 - endpoint_0, endpoint_0 - np.array([a_x, b_x]))/np.linalg.norm(endpoint_1 - endpoint_0)

df['euclidean_distance'] = df.apply(lambda x: get_euclidean_distance(x.a, x.b), axis=1)
df['stability'] = df.apply(lambda x: new._retrieve_stability_individual(int(x.id))[0], axis=1)
df['class'] = labels
print(df)
# Out:
#                a          b  male  id  euclidean_distance  stability  class
# index
# 20      3.674841  10.527960     1   0           -3.065619   0.386667      1
# 31      6.302559  10.326288     0   1           -3.600092   0.933333      1
# 23     13.022998   8.077314     1   2           -3.301714   0.386667      1
# 4       7.807282  10.641737     1   3           -4.320203   0.386667      1
# 8      17.590225  -1.866832     0   4            4.987154   0.360000      0
# 49     13.665585   9.399281     1   5           -4.749986   0.386667      1
# 18     19.533959   7.394593     1   6           -4.450183   0.373333      1
# 12      0.284000  10.615357     1   7           -2.209855   0.386667      1
# 40     13.783839 -19.266793     0   8           22.760453   0.360000      0
# 45     26.096158   6.606337     1   9           -5.511452   0.373333      1
# 22     11.588354 -10.293834     0  10           14.747426   0.360000      0
# 28     10.309102 -15.875044     0  11           20.464549   0.360000      0
# 47     13.151833 -10.602302     0  12           14.610508   0.360000      0
# 27     -5.779117  12.846769     1  13           -2.673529   0.386667      1
# 48     11.375774  -4.878652     0  14            9.603272   0.360000      0
# 26     20.549949   7.463783     1  15           -4.798235   0.373333      1
# 9      16.818857   9.447381     1  16           -5.670099   0.386667      1
# 15     24.617950   5.719115     1  17           -4.249311   0.346667      1
# 33     12.178208   0.483908     0  18            4.228380   0.360000      0
# 13     22.973474   7.847482     1  19           -5.838560   0.426667      1
# 1       7.758093   2.866289     0  20            3.164309   0.293333      0
# 2      12.409632   2.078656     0  21            2.631962   0.306667      0
# 37     15.118039 -28.229776     0  22           31.002591   0.360000      0
# 0      15.979427 -28.787773     0  23           31.300006   0.360000      0
# 46      7.118019   6.773804     1  24           -0.412757   0.346667      1
# 42     25.979765   5.940964     1  25           -4.839884   0.346667      1
# 25     16.250953 -28.947064     0  26           31.377807   0.360000      0
# 14     11.645455 -27.068026     0  27           30.848739   0.360000      0
# 34     14.818515 -23.134092     0  28           26.189517   0.360000      0
# 16      2.511160  -1.432883     0  29            8.749215   0.453333      0
# 24     12.982104  -8.017408     0  30           12.173904   0.360000      0
# 39      2.157592 -15.208184     0  31           22.082919   0.453333      0
# 19      4.057696  10.629828     1  32           -3.269601   0.386667      1
# 38      6.995736 -14.096321     1  33           19.673765   0.946667      0
# 7      11.440276 -11.787997     0  34           16.224099   0.360000      0
# 36     19.176588   7.235894     1  35           -4.198659   0.373333      1
# 21     17.347118  -5.135771     0  36            8.195422   0.360000      0
# 17      9.606250  -1.624628     0  37            6.967116   0.360000      0
# 35      7.532118  10.848228     1  38           -4.442348   0.386667      1
# 3       6.038349 -23.142847     0  39           28.631265   0.400000      0
# 29     12.691980   8.401020     1  40           -3.521002   0.386667      1
# 11     -5.401310  13.844243     1  41           -3.736637   0.386667      1
# 10      5.381261  11.895412     1  42           -4.852424   0.386667      1
# 41     13.617455   1.841625     0  43            2.524972   0.306667      0
# 5       1.982810  11.064654     1  44           -3.112361   0.386667      1
# 43     11.110598  11.968945     1  45           -6.510906   0.386667      1
# 6       5.404613  10.982430     0  46           -3.981676   0.920000      0
# 30     12.477635   8.943453     1  47           -3.982784   0.386667      1
# 32     -8.381404  15.455396     1  48           -4.458777   0.373333      1
# 44     17.942810 -15.607032     0  49           18.091429   0.360000      0

# %%
df_high = df[df['stability'] > 0.8]
df_high
# Out:
#               a          b  male  id  euclidean_distance  stability  class
# index
# 31     6.302559  10.326288     0   1           -3.600092   0.933333      1
# 38     6.995736 -14.096321     1  33           19.673765   0.946667      0
# 6      5.404613  10.982430     0  46           -3.981676   0.920000      0

# %%
plt.scatter(df['euclidean_distance'], df['stability'])
plt.xlabel('Euclidean distance')
plt.ylabel('stability')
plt.show()

# %%
print(df.corr()['euclidean_distance']['stability'])
# Out:
# -0.05150530866544508

# %%
plt.scatter(np.abs(df['euclidean_distance']), df['stability'])
plt.xlabel('Euclidean distance')
plt.ylabel('stability')
plt.show()

# %%
new._calculate_subgroup_stability()
s, m_marg = new._retrieve_stability_subgroup('1')
print(f'Male {m_marg}')
s, f_marg = new._retrieve_stability_subgroup('0')
print(f'Female {f_marg}')
# Out:
# Male Marginals:
#
# a: 0.96
# b: 0.136
# ab: 0.1136
#
# Female Marginals:
#
# a: 0.9744
# b: 0.1344
# ab: 0.1136

# %%
from scipy.stats import pearsonr
coefs = [w1[0], w2[0]]
m_ab_marg = [0.96, 0.136] # marg output is a string so this is manual for now
f_ab_marg = [0.9744, 0.1344]

print(f'Logistic regression coefs: {coefs}')
print(f'M correlation with feature importance: {pearsonr(coefs, m_ab_marg)[0]}')
print(f'F correlation with feature importance: {pearsonr(coefs, f_ab_marg)[0]}')
# Out:
# Logistic regression coefs: [0.20758739379745178, 0.7196943329164067]
# M correlation with feature importance: -1.0
# F correlation with feature importance: -1.0
